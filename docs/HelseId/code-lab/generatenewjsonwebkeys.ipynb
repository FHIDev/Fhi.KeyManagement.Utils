# %% [markdown]
# # Generate new Json Web keys command

# %%
dotnet tool install --global Fhi.HelseIdSelvbetjening.CLI --version 1.0.0

$keyFileName = ""
$keyDirectory = ""

helseid-cli generatejsonwebkey --KeyFileNamePrefix $keyFileName --KeyDirectory $keyDirectory
